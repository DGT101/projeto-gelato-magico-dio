# %%
import pandas as pd

df = pd.read_csv('/home/davi/Documentos/projeto-gelato-magico-dio/inputs/dados_sorveteria.csv')

# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=df, x='temperatura', y='vendas')
plt.title('Vendas de Sorvete vs. Temperatura')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Vendas (Unidades)')
plt.show()
